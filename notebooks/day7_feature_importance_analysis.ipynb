# %%
# DAY 7 - FEATURE IMPORTANCE ANALYSIS
# Member 2 - Context Specialist


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
# LOAD DATASET


df = pd.read_csv("contextual_feature_engineered_ai4i.csv")

print("Dataset Loaded")
print(df.shape)
# Out:
# Dataset Loaded
# (10000, 24)

# %%
# DEFINE FEATURES


features = [
    "Air temperature [K]",
    "Process temperature [K]",
    "Rotational speed [rpm]",
    "Torque [Nm]",
    "Tool wear [min]",
    "Type",
    "temp_difference",
    "ambient_temperature",
    "factory_load",
    "humidity",
    "temp_gap",
    "load_torque_interaction",
    "humidity_temp_interaction"
]

X = df[features]
y = df["Machine failure"]

# %%
# TRAIN SIMPLE MODEL


model = RandomForestClassifier(random_state=42)

model.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# FEATURE IMPORTANCE


importance = pd.Series(
    model.feature_importances_,
    index=features
)

importance = importance.sort_values(ascending=True)

# %%
# PLOT FEATURE IMPORTANCE


plt.figure(figsize=(10,6))

importance.plot(kind="barh")

plt.title("Feature Importance Analysis")

plt.xlabel("Importance Score")

plt.show()

# %%
# TOP FEATURES PRINT


print("\nTop Features:\n")

print(importance.sort_values(ascending=False).head(10))
# Out:
# Top Features:
#
# Torque [Nm]                  0.224547
# Rotational speed [rpm]       0.201746
# temp_difference              0.123055
# Tool wear [min]              0.108053
# load_torque_interaction      0.085145
# Air temperature [K]          0.043603
# ambient_temperature          0.037443
# humidity_temp_interaction    0.036036
# Process temperature [K]      0.036000
# temp_gap                     0.035539
# dtype: float64
